# %%
import os
import pathlib
import numpy as np
import matplotlib.pyplot as plt
import tqdm

# %%
flip_probability = [0, 20, 40, 60, 80, 100]
ave_p_frame_bpps = [0.05485085227272727,
                      0.053430397727272726,
                      0.05270951704545455,
                      0.05169744318181818,
                      0.05111860795454545,
                      0.03587713068181818]
ave_p_frame_qualitys = [36.87522648204457,
                         36.733118570501155,
                         36.5058492972634,
                         35.93460276517001,
                         34.495164368369366,
                         29.09209125172008]

plt.plot(flip_probability, ave_p_frame_qualitys)
plt.xlabel('Flip probability')
plt.ylabel('Ave P Frame Qualitys') 
plt.show()

# %%
plt.plot(flip_probability, ave_p_frame_bpps)
plt.xlabel('Flip probability')
plt.ylabel('Ave P Frame BPPs') 
plt.show()

# %%
plt.plot(ave_p_frame_bpps, ave_p_frame_qualitys)
plt.xlabel('Ave P Frame BPPs')
plt.ylabel('Ave P Frame Qualitys') 
plt.show()
