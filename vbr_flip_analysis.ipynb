# %%
import os
import pathlib
import numpy as np
import matplotlib.pyplot as plt
import tqdm

# %%
flip_probability = [0, 20, 40, 60, 80, 100]
ave_all_frame_bpps = [0.058190104166666666,
                      0.05688802083333333,
                      0.05622721354166667,
                      0.055299479166666665,
                      0.054768880208333336,
                      0.040797526041666664]
ave_all_frame_qualitys = [36.87658837636312,
                         36.746322790781655,
                         36.53799262364706,
                         36.01434996922811,
                         34.69486477216085,
                         29.742047748565675]

plt.plot(flip_probability, ave_all_frame_qualitys)
plt.xlabel('Flip probability')
plt.ylabel('Ave All Frame Qualitys') 
plt.show()

# %%
plt.plot(flip_probability, ave_all_frame_bpps)
plt.xlabel('Flip probability')
plt.ylabel('Ave All Frame BPPs') 
plt.show()

# %%
plt.plot(ave_all_frame_bpps, ave_all_frame_qualitys)
plt.xlabel('Ave All Frame BPPs')
plt.ylabel('Ave All Frame Qualitys') 
plt.show()
