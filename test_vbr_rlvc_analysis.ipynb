# %%
import matplotlib.pyplot as plt

# %%
flip_probability = [0, 20, 40, 60, 80, 100]

rlvc_ave_p_frame_bpps = [0.06032049005681818,
                    0.059290660511363634,
                    0.057053444602272727,
                    0.05701793323863636,
                    0.054731889204545456,
                    0.028835227272727273]
rlvc_ave_p_frame_qualitys = [36.736278707330875,
                        36.61853866577148,
                        36.41444896351207,
                        35.97841550653631,
                        35.00885774439031,
                        29.756039931557396]

dcvc_ave_p_frame_bpps = [0.05774147727272727,
                         0.056321022727272727,
                         0.05662286931818182,
                         0.05518465909090909,
                         0.05381747159090909,
                         0.037038352272727275]
dcvc_ave_p_frame_qualitys = [36.736278707330875,
                             36.61930625221946,
                             36.60653995167125,
                             36.37445633628152,
                             34.68097270618785,
                             29.756039931557396]

plt.plot(flip_probability, rlvc_ave_p_frame_qualitys, label='RLVC')
plt.plot(flip_probability, dcvc_ave_p_frame_qualitys, label='DCVC')

leg = plt.legend(loc='lower center')

plt.xlabel('Flip probability')
plt.ylabel('Ave P Frame Qualitys') 
plt.show()

# %%
plt.plot(flip_probability, rlvc_ave_p_frame_bpps, label='RLVC')
plt.plot(flip_probability, dcvc_ave_p_frame_bpps, label='DCVC')

leg = plt.legend(loc='lower center')

plt.xlabel('Flip probability')
plt.ylabel('Ave P Frame BPPs') 
plt.show()

# %%
plt.plot(rlvc_ave_p_frame_bpps, rlvc_ave_p_frame_qualitys, label='RLVC')
plt.plot(dcvc_ave_p_frame_bpps, dcvc_ave_p_frame_qualitys, label='DCVC')

leg = plt.legend(loc='lower center')

plt.xlabel('Ave P Frame BPPs')
plt.ylabel('Ave P Frame Qualitys') 
plt.show()
