# %%
import os
import pathlib
import numpy as np
import matplotlib.pyplot as plt
import tqdm

# %%
rlvc_psnrs = [
    41.39223190717439,
    39.69838673812176,
    38.39112746723698,
    37.193034410792926,
    35.88298408303615
]
rlvc_bpps = [
     0.9082677974353321,
     0.4044473416372722,
     0.1724388769473839,
     0.07633766626249264,
     0.041328027630805404
]
rlvc_crfs = [7, 11, 15, 19, 23]

rlvc_qp_psnrs = [
    39.35463899091435,
    37.88865280860241,
    36.53648372933784,
    35.15690292240703,
    33.62761916108098,
    32.01657786715828
]
rlvc_qp_bpps = [
    0.3385204879482657,
    0.14366320179306288,
    0.06870997115667254,
    0.03930406746031746,
    0.022841112764550264,
    0.012522704475308644
]
rlvc_qp_qps = [19, 23, 27, 31, 35, 39]


rlvc_gop_psnrs = [
    42.053314390961596,
    38.393306005752706,
    37.20243692053829,
    35.93351101428699
]
rlvc_gop_bpps = [
    0.898768251212522,
    0.1948926412771899,
    0.0925809551366843,
    0.053136086309523815
]
rlvc_gop_crfs = [7, 15, 19, 23]

rlvc_zerolatency_psnrs = [
    43.479786774413,
    40.471660590498324,
    38.535625241735254,
    36.95897334105724,
    35.58867378365959
]
rlvc_zerolatency_bpps = [
    1.379748998750735,
    0.7057948908730161,
    0.27574664719282777,
    0.1087815182245738,
    0.05054966012639624
]
rlvc_zerolatency_crfs = [7, 11, 15, 19, 23]

dcvc_psnrs = [
    36.90813742678982,
    35.53633780151693,
    34.07244152476825,
    32.47177744920828
]
dcvc_bpps = [
    0.10118948315817212,
    0.05722135126023065,
    0.033703138563368054,
    0.01947206914992559
]
dcvc_qps = [27, 31, 35, 39]

plt.plot(rlvc_bpps, rlvc_psnrs, label='RLVC Params (Fully Optimized)')
plt.plot(rlvc_qp_bpps, rlvc_qp_psnrs, label='Fixed QP')
plt.plot(rlvc_gop_bpps, rlvc_gop_psnrs, label='Fixed GOP')
plt.plot(rlvc_zerolatency_bpps, rlvc_zerolatency_psnrs, label='Zero Latency (no B-frames)')
plt.plot(dcvc_bpps, dcvc_psnrs, label='DCVC Params')
plt.legend(loc='lower right')
plt.title('DCVC Settings vs. x265 Quality')
plt.xlabel('bpp')
plt.ylabel('PSNR (dB)') 
plt.xlim(0, 0.2)
plt.ylim(34, 39)
plt.show()
